# %% [markdown]
# importing Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('mobile_cleaned.csv')

# %% [markdown]
# To show first 5 rows

# %%
df.head()
# Out:
#    PhoneId  Pixel Density  Screen Size  Weight  RAM  Processor_frequency  \
# 0        0            403         6.26     182    4                  1.8
# 1        1            271         6.20     168    3                  1.8
# 2        2            409         6.30     168    3                  2.1
# 3        4            411         6.00     169    4                  2.2
# 4        5            396         6.50     175    4                  2.2
#
#    Screen to Body Ratio (calculated)  Height  Internal Memory  Capacity  \
# 0                              80.68   157.9               64      4000
# 1                              80.85   156.2               32      4230
# 2                              83.68   157.0               32      3500
# 3                              74.78   159.8               64      3300
# 4                              84.23   160.4               64      3750
#
#     ...    os_name_Tizen  os_name_iOS  SIM Slot(s)_Dual SIM, GSM+CDMA  \
# ...

# %% [markdown]
# To show last 5 rows

# %%
df.tail()
# Out:
#      PhoneId  Pixel Density  Screen Size  Weight  RAM  Processor_frequency  \
# 336      465            220          5.0     141    1                  1.2
# 337      466            401          5.5     165    4                  1.8
# 338      468            282          5.2     160    3                  1.4
# 339      470            218          4.5     156    1                  1.3
# 340      472            401          5.5     153    3                  1.8
#
#      Screen to Body Ratio (calculated)  Height  Internal Memory  Capacity  \
# 336                              67.20   142.7               16      2420
# 337                              69.95   156.5               64      3000
# 338                              68.52   149.7               16      3000
# 339                              63.93   132.0                8      1800
# 340                              74.21   151.1               32      3000
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Functions available in the object

# %%
dir(df)
# Out:
# ['Brand_Apple',
#  'Brand_Asus',
#  'Brand_Billion',
#  'Brand_Blackberry',
#  'Brand_Comio',
#  'Brand_Coolpad',
#  'Brand_Do',
#  'Brand_Gionee',
#  'Brand_Google',
#  'Brand_HTC',
#  'Brand_Honor',
#  'Brand_Huawei',
#  'Brand_InFocus',
#  'Brand_Infinix',
#  'Brand_Intex',
#  'Brand_Itel',
#  'Brand_Jivi',
#  'Brand_Karbonn',
#  'Brand_LG',
#  'Brand_Lava',
#  'Brand_LeEco',
#  'Brand_Lenovo',
#  'Brand_Lephone',
#  'Brand_Lyf',
#  'Brand_Meizu',
#  'Brand_Micromax',
#  'Brand_Mobiistar',
#  'Brand_Moto',
#  'Brand_Motorola',
#  'Brand_Nokia',
#  'Brand_Nubia',
#  'Brand_OPPO',
#  'Brand_OnePlus',
#  'Brand_Oppo',
#  'Brand_Panasonic',
#  'Brand_Razer',
#  'Brand_Realme',
#  'Brand_Reliance',
#  'Brand_Samsung',
#  'Brand_Sony',
#  'Brand_Spice',
#  'Brand_Tecno',
#  'Brand_Ulefone',
#  'Brand_VOTO',
#  'Brand_Vivo',
#  'Brand_Xiaomi',
#  'Brand_Yu',
#  'Brand_iVooMi',
#  'Capacity',
#  'Height',
#  'Num_cores_312',
#  'Num_cores_Deca',
#  'Num_cores_Dual',
#  'Num_cores_Hexa',
# ...

# %%
len(df)
# Out:
# 341

# %%
df.shape  #Returns rows and columns
# Out:
# (341, 88)

# %% [markdown]
# Retriving the particular row for the data

# %%
df.loc[4]
# Out:
# PhoneId                                         5.00
# Pixel Density                                 396.00
# Screen Size                                     6.50
# Weight                                        175.00
# RAM                                             4.00
# Processor_frequency                             2.20
# Screen to Body Ratio (calculated)              84.23
# Height                                        160.40
# Internal Memory                                64.00
# Capacity                                     3750.00
# Resolution                                     16.00
# SIM 2_2G                                        0.00
# SIM 2_3G                                        0.00
# SIM 2_4G                                        1.00
# SIM 2_Other                                     0.00
# Num_cores_312                                   0.00
# Num_cores_Deca                                  0.00
# Num_cores_Dual                                  0.00
# ...

# %% [markdown]
# To select the subste of the rows

# %%
df_short = df[20:40]

# %%
df_short.shape
# Out:
# (20, 88)

# %%
df_short.head()
# Out:
#     PhoneId  Pixel Density  Screen Size  Weight  RAM  Processor_frequency  \
# 20       30            271         6.20     168    4                  1.8
# 21       31            403         6.26     182    6                  1.8
# 22       33            270         6.22     143    2                  2.0
# 23       34            287         5.86     151    3                  1.8
# 24       36            274         6.00     178    2                  1.4
#
#     Screen to Body Ratio (calculated)  Height  Internal Memory  Capacity  \
# 20                              81.22   155.9               64      4230
# 21                              80.68   157.9               64      4000
# 22                              82.66   155.0               16      3260
# 23                              79.34   149.5               32      3060
# 24                              73.94   161.4               32      3300
#
#      ...    os_name_Tizen  os_name_iOS  SIM Slot(s)_Dual SIM, GSM+CDMA  \
# ...

# %%
df_thin = df[['PhoneId','Screen Size','Weight','SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE','Capacity']]

# %%
df_thin.shape
# Out:
# (341, 5)

# %%
df_thin.head()
# Out:
#    PhoneId  Screen Size  Weight  SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE  \
# 0        0         6.26     182                                          1
# 1        1         6.20     168                                          1
# 2        2         6.30     168                                          1
# 3        4         6.00     169                                          0
# 4        5         6.50     175                                          1
#
#    Capacity
# 0      4000
# 1      4230
# 2      3500
# 3      3300
# 4      3750

# %%
#Selecting a particular row which has 'SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE	'==1
df_select = df_thin[df_thin['SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE']==1]

# %%
df_select.shape
# Out:
# (52, 5)

# %%
df_select.head()
# Out:
#    PhoneId  Screen Size  Weight  SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE  \
# 0        0         6.26     182                                          1
# 1        1         6.20     168                                          1
# 2        2         6.30     168                                          1
# 4        5         6.50     175                                          1
# 5        7         6.41     156                                          1
#
#    Capacity
# 0      4000
# 1      4230
# 2      3500
# 4      3750
# 5      3400

# %% [markdown]
# Some simple computations

# %%
df_select['Screen Size'].describe()
# Out:
# count    52.000000
# mean      6.102115
# std       0.303995
# min       5.450000
# 25%       5.990000
# 50%       6.200000
# 75%       6.285000
# max       6.590000
# Name: Screen Size, dtype: float64

# %%
df_thin['Screen Size'].describe()
# Out:
# count    341.000000
# mean       5.462317
# std        0.742529
# min        2.400000
# 25%        5.200000
# 50%        5.500000
# 75%        6.000000
# max        6.590000
# Name: Screen Size, dtype: float64

# %%
#for all the columns
df_thin.describe()
# Out:
#           PhoneId  Screen Size      Weight  \
# count  341.000000   341.000000  341.000000
# mean   232.970674     5.462317  161.343109
# std    137.231746     0.742529   22.305556
# min      0.000000     2.400000   58.000000
# 25%    110.000000     5.200000  150.000000
# 50%    229.000000     5.500000  161.000000
# 75%    354.000000     6.000000  172.000000
# max    472.000000     6.590000  330.000000
#
#        SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE      Capacity
# count                                 341.000000    341.000000
# mean                                    0.152493   3191.307918
# std                                     0.360026    932.533527
# min                                     0.000000   1020.000000
# 25%                                     0.000000   2900.000000
# 50%                                     0.000000   3055.000000
# 75%                                     0.000000   3750.000000
# max                                     1.000000  13000.000000

# %%
#Alternate way of 'SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE'==1 and mean of 'Screen Size'
df_thin[df_thin['SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE']==1]['Screen Size'].mean()
# Out:
# 6.102115384615386

# %%
#Alternate way of 'SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE'==0 and mean of 'Screen Size'
df_thin[df_thin['SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE']==0]['Screen Size'].mean()
# Out:
# 5.347197231833918

# %%
g = df_thin.groupby(['SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE']) #TO group as 0 and 1

# %%
for key,df_key in g:
    print(key)
    print(df_key)
# Out:
# 0
#      PhoneId  Screen Size  Weight  SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE  \
# 3          4         6.00     169                                          0
# 7          9         5.84     178                                          0
# 8         10         6.20     168                                          0
# 10        14         6.41     185                                          0
# 12        17         5.84     152                                          0
# 13        18         6.30     150                                          0
# 17        23         6.22     161                                          0
# 20        30         6.20     168                                          0
# 22        33         6.22     143                                          0
# 24        36         6.00     178                                          0
# 25        37         5.99     170                                          0
# ...

# %%
df_thin.groupby(['SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE']).mean()
# Out:
#                                               PhoneId  Screen Size  \
# SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE
# 0                                          256.636678     5.347197
# 1                                          101.442308     6.102115
#
#                                                Weight     Capacity
# SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE
# 0                                          160.038062  3100.159170
# 1                                          168.596154  3697.884615

# %%
df_thin.groupby(['SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE']).describe()
# Out:
#                                           Capacity                           \
#                                              count         mean         std
# SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE
# 0                                            289.0  3100.159170  967.204306
# 1                                             52.0  3697.884615  453.865042
#
#                                                                            \
#                                               min     25%     50%     75%
# SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE
# 0                                          1020.0  2716.0  3000.0  3400.0
# 1                                          3000.0  3400.0  3750.0  4000.0
#
#                                                    PhoneId              ...    \
#                                                max   count        mean  ...
# SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE                               ...
# ...

# %% [markdown]
# For plotting

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
sx = sns.pairplot(df_thin, diag_kind='hist') #To provide pair of plots in histogram
